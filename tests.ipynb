# %%
x = "Fiorela"
def funtion_():
    return x
print(funtion_()) #error
# Out:
# Fiorela

# %%
x = ["Fiorela","fio"]
def funtion():
    for text in x:
        return text
print(funtion())
# Out:
# Fiorela
